# %% [markdown]
# <a href="https://colab.research.google.com/github/binary-study/DemoBinary/blob/main/Refined_AGCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/MyDrive/Refined-AGCN
# Out:
# /content/gdrive/MyDrive/Refined-AGCN

# %%
! git clone https://github.com/YangDi666/2s-AGCN-For-Daily-Living.git
# Out:
# Cloning into '2s-AGCN-For-Daily-Living'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 87 (delta 29), reused 61 (delta 15), pack-reused 0
# Unpacking objects: 100% (87/87), done.

# %%
! pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 122kB 16.0MB/s
# ...

# %%
cd /content/gdrive/MyDrive/Refined-AGCN/2s-AGCN-For-Daily-Living/data_gen
# Out:
# /content/gdrive/MyDrive/Refined-AGCN/2s-AGCN-For-Daily-Living/data_gen

# %%
! python smarthome_gendata.py
# Out:
# raw_path:  /content/gdrive/MyDrive/data/toyota_smarthome_skeletons_refined/
# xsub val
# tcmalloc: large alloc 3911761920 bytes == 0x562827c06000 @  0x7fa6b802d001 0x7fa6b581954f 0x7fa6b5869b58 0x7fa6b586db17 0x7fa6b590c203 0x5628251930e4 0x562825192de0 0x5628252076f5 0x562825201b0e 0x56282519477a 0x56282520386a 0x562825201b0e 0x562825201813 0x5628252cb592 0x5628252cb90d 0x5628252cb7b6 0x5628252a3103 0x5628252a2dac 0x7fa6b6e15bf7 0x5628252a2c8a
# 100% 5433/5433 [28:17<00:00,  3.20it/s]

# %% [markdown]
# ## **Test with weight1 batch 64**

# %%
cd ..
# Out:
# /content/gdrive/My Drive/Refined-AGCN/2s-AGCN-For-Daily-Living

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.12781954887218044
# accuracy_Cook.Cleanup :  0.07476635514018691
# accuracy_Cook.Cut :  0.0
# accuracy_Cook.Stir :  0.04522613065326633
# accuracy_Cook.Usestove :  0.1111111111111111
# accuracy_Cutbread :  0.1
# accuracy_Drink.Frombottle :  0.3560606060606061
# accuracy_Drink.Fromcan :  0.025210084033613446
# accuracy_Drink.Fromcup :  0.5073627844712182
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.3201581027667984
# accuracy_Eat.Snack :  0.28846153846153844
# accuracy_Enter :  0.16541353383458646
# accuracy_Getup :  0.4889589905362776
# accuracy_Laydown :  0.2923076923076923
# accuracy_Leave :  0.09345794392523364
# accuracy_Makecoffee.Pourgrains :  0.0
# accuracy_Makecoffee.Pourwater :  0.5185185185185185
# accuracy_Maketea.Boilwater :  0.0625
# accuracy_Maketea.Insertteabag :  0.05
# accuracy_Pour.Frombottle :  0.5865384615384616
# accuracy_Pour.Fromcan :  0.0
# accuracy_Pour.Fromkettle :  0.17857142857142858
# ...

# %% [markdown]
# ## **Test with Weight2 batch 64**

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.3458646616541353
# accuracy_Cook.Cleanup :  0.5046728971962616
# accuracy_Cook.Cut :  0.22058823529411764
# accuracy_Cook.Stir :  0.46733668341708545
# accuracy_Cook.Usestove :  0.16666666666666666
# accuracy_Cutbread :  0.05
# accuracy_Drink.Frombottle :  0.16666666666666666
# accuracy_Drink.Fromcan :  0.05042016806722689
# accuracy_Drink.Fromcup :  0.8527443105756358
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.6482213438735178
# accuracy_Eat.Snack :  0.038461538461538464
# accuracy_Enter :  0.8947368421052632
# accuracy_Getup :  0.886435331230284
# accuracy_Laydown :  0.9076923076923077
# accuracy_Leave :  0.8037383177570093
# accuracy_Makecoffee.Pourgrains :  0.047619047619047616
# accuracy_Makecoffee.Pourwater :  0.7777777777777778
# accuracy_Maketea.Boilwater :  0.125
# accuracy_Maketea.Insertteabag :  0.0
# accuracy_Pour.Frombottle :  0.46153846153846156
# accuracy_Pour.Fromcan :  0.0
# ...

# %% [markdown]
# ## **Test with weight3 batch64**

# %%
! python main.py --config ./config/smarthome-cross-subject/test_joint.yaml
# Out:
# <class 'model.agcn.Model'>
# Model(
#   (data_bn): BatchNorm1d(45, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): TCN_GCN_unit(
#     (gcn1): unit_gcn(
#       (conv_a): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_b): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_d): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (down): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
! python evaluation.py runs/smarthome_cs_agcn_test_joint_right.txt 31
# Out:
# accuracy_Cook.Cleandishes :  0.5639097744360902
# accuracy_Cook.Cleanup :  0.5794392523364486
# accuracy_Cook.Cut :  0.5294117647058824
# accuracy_Cook.Stir :  0.8592964824120602
# accuracy_Cook.Usestove :  0.2777777777777778
# accuracy_Cutbread :  0.15
# accuracy_Drink.Frombottle :  0.2803030303030303
# accuracy_Drink.Fromcan :  0.2184873949579832
# accuracy_Drink.Fromcup :  0.8594377510040161
# accuracy_Drink.Fromglass :  0.0
# accuracy_Eat.Attable :  0.7233201581027668
# accuracy_Eat.Snack :  0.17307692307692307
# accuracy_Enter :  0.8571428571428571
# accuracy_Getup :  0.889589905362776
# accuracy_Laydown :  0.8461538461538461
# accuracy_Leave :  0.8130841121495327
# accuracy_Makecoffee.Pourgrains :  0.09523809523809523
# accuracy_Makecoffee.Pourwater :  0.5185185185185185
# accuracy_Maketea.Boilwater :  0.3125
# accuracy_Maketea.Insertteabag :  0.55
# accuracy_Pour.Frombottle :  0.6634615384615384
# accuracy_Pour.Fromcan :  0.0
# accuracy_Pour.Fromkettle :  0.75
# ...
